# %% [markdown]
# # 2. Extraction de la liste des comptes suivis par les utilisateurs

# %% [markdown]
# A partir de la liste en entrée (cellule ci-après), scrapper et créer un fichier texte qui contient la liste de tous les comptes suivis par les utilisateurs. La liste a été divisée en trois pour aller plus vite.

# %%
f = open("users_to_scrap.txt", 'r')    
three_rows=[]

for line in f:
    rows=line.split('\t')
    three_rows.append(rows)

users01 = three_rows[0]       #Gabriel : three_rows[0], Hugo three_rows[1] et Yann three_rows[2]

# %%
len(users01)
# Out:
# 1060

# %%
# Fichiers à faire tourner au fur et à mesure

#users1=users01[:250]
#users1=['ajibmajib1','maria_from_dubai','naiscoste','hernan7018','meganef__','theinsidemoonblog','emma.lathuraz','sam_vyi','spidercherixmartin','zgmail.com6','alex___janiak','sellune','lauraflid','fansofhailee','gazelioline','alicelefbv','linstajuly','couple_goals_adult','juu28o6','avocado__salsa','ehmanue','katiasanch','lorreelodie','lily_basic','hasan197666']
#users1=users01[251:351]
#users1=users01[352:700]
#users1 = ['lo_de89','bellizina','willytipi1759']
#users1=users01[701:1000]
#users1=['522majid','israel_juarez537','cecile.sabin23','emiblabliblu','morganedot','f__justine','marianne_dprx','marion.victorias','johana.pinzon3','fanie209','thania_souza_19','charlottebrd02','saptaparna_patra','melvin_d_wonpea','demberelmanaljav']
#users1=users01[1001:]
users1=['gialvarez','wellnessandcoconut','lune.poetique','vaniya_serenkiy','wise1829','summersandilands','coco_jms','enola_lit','aurerato']

# %%
dataFile = open('usernames.txt', 'w') #changer le directory
for usr in users1:
    dataFile.write(str(usr)+'\t')

# %%
len(users1)
# Out:
# 9

# %%
#attention à changer le directory dans le script (ligne 22)
# !python script.py
# Out:
# user proceeded: gialvarez
# Extract following % 0.0 from %100
# Extract following % 0.94 from %100
# Extract following % 1.89 from %100
# Extract following % 2.83 from %100
# Extract following % 3.77 from %100
# Extract following % 4.72 from %100
# Extract following % 5.66 from %100
# Extract following % 6.6 from %100
# Extract following % 7.55 from %100
# Extract following % 8.49 from %100
# Extract following % 9.43 from %100
# Extract following % 10.38 from %100
# Extract following % 11.32 from %100
# Extract following % 12.26 from %100
# Extract following % 13.21 from %100
# Extract following % 14.15 from %100
# Extract following % 15.09 from %100
# Extract following % 16.04 from %100
# Extract following % 16.98 from %100
# Extract following % 17.92 from %100
# Extract following % 18.87 from %100
# Extract following % 19.81 from %100
# Extract following % 20.75 from %100
# Extract following % 21.7 from %100
# Extract following % 22.64 from %100
# ...
